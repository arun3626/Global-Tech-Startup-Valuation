# %% [markdown]
# # Global Tech Startup Valuation Analysis

# %%
import pandas as pd
df=pd.read_csv('../data_processed/cleaned_startups.csv')
df.shape

# %%
df.describe(include='all').T

# %%
df.groupby('Funding_Stage')['Valuation_USD_Millions'].mean().sort_values(ascending=False)

# %%
df.groupby('Country')['Valuation_USD_Millions'].mean().sort_values(ascending=False).head(15)
